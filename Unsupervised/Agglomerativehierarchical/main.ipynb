# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch

# %%
data, _ = make_blobs(n_samples=100, centers=4, cluster_std=0.60, random_state=0)

# %%
plt.scatter(data[:, 0], data[:, 1], s=10)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Generated Data")
plt.show()

# %%
agglomerative_cluster = AgglomerativeClustering(n_clusters=4)
labels = agglomerative_cluster.fit_predict(data)

# %%
plt.scatter(data[:, 0], data[:, 1], c=labels, s=10, cmap='viridis')
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Agglomerative Hierarchical Clustering")
plt.show()

# %%
# Plot the dendrogram
plt.figure(figsize=(30, 10))
dendrogram = sch.dendrogram(sch.linkage(data, method='ward'))
plt.title("Dendrogram")
plt.xlabel("Data Points")
plt.ylabel("Distance")
plt.show()
